# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Data Science & Analytics\Movies and TV recommendation project\Data\netflix_titles.csv", encoding="latin1")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8809 entries, 0 to 8808
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8809 non-null   object
#  1   type          8809 non-null   object
#  2   title         8809 non-null   object
#  3   director      6175 non-null   object
#  4   cast          7984 non-null   object
#  5   country       7978 non-null   object
#  6   date_added    8799 non-null   object
#  7   release_year  8809 non-null   int64
#  8   rating        8805 non-null   object
#  9   duration      8806 non-null   object
#  10  listed_in     8809 non-null   object
#  11  description   8809 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 826.0+ KB

# %% [markdown]
# ## Initial Observations
# - Dataset contains both Movies and TV Shows
# - Multiple categorical and text-based columns
# - Missing values are present in some columns
# - Dataset is suitable for analysis and recommendation

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df['director']=df['director'].fillna('unknown')
# Out:
# C:\Users\Girish S\AppData\Local\Temp\ipykernel_48516\1495151129.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['director']=df['director'].fillna('unknown')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['cast'] = df['cast'].fillna('Unknown')
df['country'] = df['country'].fillna('Unknown')
df['rating'] = df['rating'].fillna('Not Rated')
df['date_added'] = df['date_added'].fillna('Unknown')
df['duration'] = df['duration'].fillna('Unknown')
# Out:
# C:\Users\Girish S\AppData\Local\Temp\ipykernel_48516\2293994227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cast'] = df['cast'].fillna('Unknown')
# C:\Users\Girish S\AppData\Local\Temp\ipykernel_48516\2293994227.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country'] = df['country'].fillna('Unknown')
# C:\Users\Girish S\AppData\Local\Temp\ipykernel_48516\2293994227.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
# Out:
# C:\Users\Girish S\AppData\Local\Temp\ipykernel_48516\3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8809 entries, 0 to 8808
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8809 non-null   object
#  1   type          8809 non-null   object
#  2   title         8809 non-null   object
#  3   director      8809 non-null   object
#  4   cast          8809 non-null   object
#  5   country       8809 non-null   object
#  6   date_added    8809 non-null   object
#  7   release_year  8809 non-null   int64
#  8   rating        8809 non-null   object
#  9   duration      8809 non-null   object
#  10  listed_in     8809 non-null   object
#  11  description   8809 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 826.0+ KB

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## Step 2: Data Cleaning Summary
#
# The dataset was cleaned to ensure accuracy and consistency before analysis and modeling.
#
# ### Cleaning Actions Performed:
# - Removed unnecessary `Unnamed` columns created during CSV export
# - Handled missing values in categorical and text columns by replacing them with meaningful placeholders
# - Filled missing values in rating, duration, and date columns to avoid null-related issues
# - Removed duplicate records to maintain data integrity
#
# ### Result:
# - Dataset contains 8,809 records and 12 relevant features
# - No missing values remain in the dataset
# - Data is now clean and ready for exploratory data analysis and recommendation modeling

# %% [markdown]
# ## Step 3: Exploratory Data Analysis (EDA)
#
# In this step, exploratory data analysis is performed to understand the distribution,
# patterns, and trends in movies and TV shows available on Netflix.

# %%
import matplotlib.pyplot as plt

type_count=df['type'].value_counts()

type_count.plot(kind='bar')
plt.title('movies vs TV Shows')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
genres=df['listed_in'].str.split(',').explode()
top_genres=genres.value_counts().head(10)
top_genres.plot(kind='bar')
plt.title('Top 10 genres on Netflix')
plt.xlabel('Genres')
plt.ylabel('count')
plt.show()

# %%
year_count=df['release_year'].value_counts()
year_count=year_count.sort_index()
year_count.plot(kind='line')
plt.title('Content Release Trend over Years')
plt.xlabel('Release Year')
plt.ylabel('number of titles')
plt.show()

# %%
rating_count=df['rating'].value_counts()
rating_count.plot(kind='bar')

plt.title('Content Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### EDA Insights:
# - Netflix contains more Movies than TV Shows
# - Drama and International content are the most popular genres
# - Content production increased significantly after 2015
# - Majority of content is targeted toward mature audiences

# %% [markdown]
# ## Step 4: Recommendation System (Content-Based)
#
# A content-based recommendation system is built using movie genres and descriptions
# to suggest similar movies and TV shows based on content similarity.

# %%
df_recommend=df[['title','listed_in','description']]
df_recommend.head()
# Out:
#                    title                                          listed_in  \
# 1          Blood & Water    International TV Shows, TV Dramas, TV Mysteries
# 2              Ganglands  Crime TV Shows, International TV Shows, TV Act...
# 3  Jailbirds New Orleans                             Docuseries, Reality TV
# 4           Kota Factory  International TV Shows, Romantic TV Shows, TV ...
# 5          Midnight Mass                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...

# %%
df_recommend['combined_text']=(df_recommend['listed_in']+''+df_recommend['description'])
# Out:
# C:\Users\Girish S\AppData\Local\Temp\ipykernel_48516\3487323893.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recommend['combined_text']=(df_recommend['listed_in']+''+df_recommend['description'])

# %%
df_recommend[['title', 'combined_text']].head()
# Out:
#                    title                                      combined_text
# 1          Blood & Water  International TV Shows, TV Dramas, TV Mysterie...
# 2              Ganglands  Crime TV Shows, International TV Shows, TV Act...
# 3  Jailbirds New Orleans  Docuseries, Reality TVFeuds, flirtations and t...
# 4           Kota Factory  International TV Shows, Romantic TV Shows, TV ...
# 5          Midnight Mass  TV Dramas, TV Horror, TV MysteriesThe arrival ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df_recommend['combined_text'])

# %%
df_recommend['combined_text']
# Out:
# 1       International TV Shows, TV Dramas, TV Mysterie...
# 2       Crime TV Shows, International TV Shows, TV Act...
# 3       Docuseries, Reality TVFeuds, flirtations and t...
# 4       International TV Shows, Romantic TV Shows, TV ...
# 5       TV Dramas, TV Horror, TV MysteriesThe arrival ...
#                               ...
# 8796    International TV Shows, TV DramasDuring the Mo...
# 8797    Kids' TVTeen surfer Zak Storm is mysteriously ...
# 8800    International TV Shows, Romantic TV Shows, TV ...
# 8803    Kids' TV, Korean TV Shows, TV ComediesWhile li...
# 8807    Sci-fi, Horror, ActionA new breed of parasitic...
# Name: combined_text, Length: 2677, dtype: object

# %%
tfidf_matrix.shape
# Out:
# (2677, 11188)

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim=cosine_similarity(tfidf_matrix,tfidf_matrix)

# %%
def recommend(title,cosine_sim=cosine_sim):
    idx=df_recommend[df_recommend['title']==title].index[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores=sorted(sim_scores,key=lambda x:x[1],reverse=True)
    sim_scores=sim_scores[1:11]
    movie_indices=[i[0] for i in sim_scores]
    return df_recommend['title'].iloc[movie_indices]

# %% [markdown]
# ### Example Recommendation Output
#
# For example, when the input title is **Kota Factory**, the system recommends
# the following similar TV shows:
#
# - Save Me
# - Diablero
# - Penny Dreadful
# - Stranger Things
# - The Originals
#
# These recommendations are based on similarity in content themes and descriptions.

# %%
recommend('Kota Factory')
# Out:
# 3074                        Save Me
# 2971                       Diablero
# 7257           La Rosa de Guadalupe
# 6167    Anjaan: Special Crimes Unit
# 7725                 Penny Dreadful
# 1906                           Evil
# 3685                Stranger Things
# 2818                      Bloodride
# 4709                  The Originals
# 1625                      The Guest
# Name: title, dtype: object

# %%
df_recommend['title'].str.contains('Inception', case=False, na=False).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Step 4: Content-Based Recommendation System
#
# In this step, a content-based recommendation system was developed to suggest
# similar movies and TV shows based on textual features such as genres and descriptions.

# %% [markdown]
# # Conclusion
#
# A functional content-based recommendation system was successfully implemented.
# The model effectively suggests relevant movies and TV shows by analyzing textual
# similarity, demonstrating the practical application of natural language processing
# and machine learning techniques.
